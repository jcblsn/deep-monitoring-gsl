# %% [markdown]
# # Visualizing processing steps for Sentinel-1 SAR imagery
#
# 2023-06-15

# %%
import geopandas as gpd
import pandas as pd
import ee
import folium
import shapely.geometry
from shapely.geometry import shape
from matplotlib import pyplot as plt

# ee.Authenticate()
ee.Initialize(project='gsl-monitoring')

# %% [markdown]
# ## Read

# %%
gdf = gpd.read_file('../../data/definitions/preliminary-roi.geojson')
polygon_geojson = shapely.geometry.mapping(gdf.loc[0, 'geometry'])
roi = ee.Geometry.Polygon(polygon_geojson['coordinates'])

collection = ee.ImageCollection('COPERNICUS/S1_GRD') \
    .filterBounds(roi) \
    .filterDate('2014-01-01', '2023-05-30') \
    .select(['VV', 'VH', 'angle'])

collection.size().getInfo()

image_ids = [
    # 'COPERNICUS/S1_GRD/S1A_IW_GRDH_1SDV_20180313T133325_20180313T133350_020997_0240CE_1D8D',
    'COPERNICUS/S1_GRD/S1A_IW_GRDH_1SDV_20180313T133350_20180313T133415_020997_0240CE_ADB5',
    # 'COPERNICUS/S1_GRD/S1B_IW_GRDH_1SDV_20180309T011826_20180309T011851_009948_01205D_494A',
    'COPERNICUS/S1_GRD/S1B_IW_GRDH_1SDV_20170331T012629_20170331T012658_004946_008A59_DC5F',
    # 'COPERNICUS/S1_GRD/S1A_IW_GRDH_1SDV_20170404T134138_20170404T134203_015995_01A623_4791',
    # 'COPERNICUS/S1_GRD/S1A_IW_GRDH_1SDV_20170404T134203_20170404T134228_015995_01A623_1DD4',
    'COPERNICUS/S1_GRD/S1A_IW_GRDH_1SDV_20230522T133414_20230522T133439_048647_05D9E0_17C0'
]

# %%
collection.first().bandNames().getInfo()
# Out:
# ['VV', 'VH', 'angle']

# %% [markdown]
# ## Function definitions

# %%
def get_image_collection(image_ids):
    def get_images(image_id):
        return ee.Image(image_id)

    images = ee.ImageCollection.fromImages(list(map(get_images, image_ids)))\
                                .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VV'))\
                                .filter(ee.Filter.eq('instrumentMode', 'IW'))
    return images

def median_filter(img, size):
    # see here https://mbonnema.github.io/GoogleEarthEngine/07-SAR-Water-Classification/
    vv = img.select('VV')
    vv_smoothed = vv.focal_median(size,'circle','pixels').rename('VV_filtered')
    vh = img.select('VH')
    vh_smoothed = vh.focal_median(size,'circle','pixels').rename('VH_filtered')
    return img.addBands(vv_smoothed).addBands(vh_smoothed)


def convert_to_linear(image):
    return ee.Image(10).pow(image.divide(10))

def normalize(img):
    stats = img.reduceRegion(
        reducer = ee.Reducer.minMax(),
        geometry = roi,
        scale = 10,
        bestEffort = True)

    min_val_VV = ee.Number(stats.get('VV_filtered_min'))
    max_val_VV = ee.Number(stats.get('VV_filtered_max'))
    min_val_VH = ee.Number(stats.get('VH_filtered_min'))
    max_val_VH = ee.Number(stats.get('VH_filtered_max'))
    min_val_VH_VV = ee.Number(stats.get('VH_VV_filtered_min'))
    max_val_VH_VV = ee.Number(stats.get('VH_VV_filtered_max'))

    quantiles = img.reduceRegion(
        reducer = ee.Reducer.percentile([1,2,98,99]),
        geometry = roi,
        scale = 10,
        bestEffort = True)

    # print(quantiles.getInfo())

    # {'VH_VV_filtered_p1': 1.3707270989343514,
    #  'VH_VV_filtered_p5': 2.6272155209216566,
    #  'VH_VV_filtered_p95': 14.876791757593027,
    #  'VH_VV_filtered_p99': 18.867862562150677,
    #  'VH_filtered_p1': 0.0008323809960359647,
    #  'VH_filtered_p5': 0.0008323809960359647,
    #  'VH_filtered_p95': 0.027817527574252796,
    #  'VH_filtered_p99': 0.057139821900548365,
    #  'VV_filtered_p1': 0.006781440620247682,
    #  'VV_filtered_p5': 0.006781440620247682,
    #  'VV_filtered_p95': 0.1481321116306729,
    #  'VV_filtered_p99': 0.27378398892299255}

    q98_val_VV = ee.Number(quantiles.get('VV_filtered_p98'))
    q98_val_VH = ee.Number(quantiles.get('VH_filtered_p98'))

    image_vv = img.select('VV_filtered').clamp(0, q98_val_VV)
    image_vh = img.select('VH_filtered').clamp(0, q98_val_VH)

    image_vv = image_vv.subtract(min_val_VV).divide(q98_val_VV.subtract(min_val_VV)).rename('VV')
    image_vh = image_vh.subtract(min_val_VH).divide(q98_val_VH.subtract(min_val_VH)).rename('VH')
    image_vh_vv = img.select('VH_VV_filtered').subtract(min_val_VH_VV).divide(max_val_VH_VV.subtract(min_val_VH_VV)).rename('VH_VV')

    # print(image_vv.reduceRegion(ee.Reducer.minMax(), roi, 10, maxPixels=1e9).getInfo())
    img_normalized = image_vv.clamp(0, 1).addBands(image_vh.clamp(0, 1)).addBands(image_vh_vv.clamp(0, 1))
    # print(img_normalized.reduceRegion(ee.Reducer.minMax(), roi, 10, maxPixels=1e9).getInfo())
    # print(ee.Number(image_vv.reduceRegion(reducer=ee.Reducer.percentile([99]),geometry=roi,scale=10,bestEffort=True).get('VV_filtered_p99')).getInfo())

    return img_normalized

def show_map(img, roi, vis_params):
    def add_ee_layer(self, ee_image_object, vis_params, name):
        map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
        folium.raster_layers.TileLayer(
            tiles=map_id_dict['tile_fetcher'].url_format,
            attr="Map Data © Google Earth Engine",
            name=name,
            overlay=True,
            control=True
        ).add_to(self)
    folium.Map.add_ee_layer = add_ee_layer
    my_map = folium.Map(location=[roi.centroid().coordinates().get(1).getInfo(),
                                  roi.centroid().coordinates().get(0).getInfo()],
                        zoom_start=9)
    my_map.add_ee_layer(img, vis_params, 'Normalized SAR Image')
    my_map.add_child(folium.LayerControl())
    return my_map

# %%
collection_subset = get_image_collection(image_ids)

# %%
# abandoned (for now) implementation of a composite image

# vh = collection_subset.filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VV')) \
#     .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VH')) \
#     .filter(ee.Filter.eq('instrumentMode', 'IW'))

# vhAscending = vh.filter(ee.Filter.eq('orbitProperties_pass', 'ASCENDING'))
# vhDescending = vh.filter(ee.Filter.eq('orbitProperties_pass', 'DESCENDING'))

# composite = ee.Image.cat([
#     vhAscending.select('VH').max(),
#     vhDescending.select('VH').max(),
#     ee.ImageCollection(vhAscending.select('VV').merge(vhDescending.select('VV'))).max(),
#     ]).focal_median()

# composite.getInfo()

# %% [markdown]
# ## Process
#
# Make linear, then apply speckle filter, then normalize

# %%
image = ee.Image(collection_subset.toList(collection_subset.size()).get(1)).clip(roi).select(['VV', 'VH', 'angle'])
image.getInfo()
# get system:index
print(image.get('system:index').getInfo())
# print(image.bandNames().getInfo(), image.reduceRegion(ee.Reducer.minMax(), roi, 10, maxPixels=1e9).getInfo())
# Out:
# S1B_IW_GRDH_1SDV_20170331T012629_20170331T012658_004946_008A59_DC5F

# %% [markdown]
# Visualize angle band distribution

# %%
print(image.bandNames().getInfo(), image.reduceRegion(ee.Reducer.minMax(), roi, 10, maxPixels=1e9).getInfo())
show_map(
    image,
    roi, 
    {
        'bands': ['angle'],
        'min': [35],
        'max': [44]
    }
)
# Out:
# ['VV', 'VH', 'angle'] {'VH_max': 24.432217201862837, 'VH_min': -73.37154462911002, 'VV_max': 36.7585282396283, 'VV_min': -70.35610879910682, 'angle_max': 44.76335144042969, 'angle_min': 36.76759338378906}
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42656ea9701480be4dbeb60d6a84b74b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42656ea9701480be4dbeb60d6a84b74b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42656ea9701480be4dbeb60d6a84b74b = L.map(
#                 &quot;map_42656ea9701480be4dbeb60d6a84b74b&quot;,
#                 {
#                     center: [41.19911137151146, -112.55089611487612],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a12cbdd39133c56074d4290b74d6230b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_42656ea9701480be4dbeb60d6a84b74b);
#
#
#             var tile_layer_891e2e916bd73f3b02531ed86b324350 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/gsl-monitoring/maps/0f7d148af1527e7126ddab821a23cf32-ec9c4507f7d4218308abba041769888b/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_42656ea9701480be4dbeb60d6a84b74b);
#
#
#             var layer_control_b496abbf476b0970f614b49d317ebacd = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a12cbdd39133c56074d4290b74d6230b,
#                 },
#                 overlays :  {
#                     &quot;Normalized SAR Image&quot; : tile_layer_891e2e916bd73f3b02531ed86b324350,
#                 },
#             };
#             L.control.layers(
#                 layer_control_b496abbf476b0970f614b49d317ebacd.base_layers,
#                 layer_control_b496abbf476b0970f614b49d317ebacd.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_42656ea9701480be4dbeb60d6a84b74b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Visualize raw VV band distribution

# %%
show_map(
    image,
    roi, 
    {
        'bands': ['VV'],
        'min': [-25],
        'max': [-5]
    }
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c5efb8a30a2089ea48152aa75c039b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c5efb8a30a2089ea48152aa75c039b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c5efb8a30a2089ea48152aa75c039b1 = L.map(
#                 &quot;map_6c5efb8a30a2089ea48152aa75c039b1&quot;,
#                 {
#                     center: [41.19911137151146, -112.55089611487612],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a488c1a9bfdd62c4b365f8ff11d3fbd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c5efb8a30a2089ea48152aa75c039b1);
#
#
#             var tile_layer_a3d4e117368afa7e144ace3e33f67a7e = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/gsl-monitoring/maps/91e3124ce8e91888d650581c7fdb9749-8762feeda458243966a888f0aff92acc/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c5efb8a30a2089ea48152aa75c039b1);
#
#
#             var layer_control_712fd87169cd2281d5f208d1e78713ef = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_3a488c1a9bfdd62c4b365f8ff11d3fbd,
#                 },
#                 overlays :  {
#                     &quot;Normalized SAR Image&quot; : tile_layer_a3d4e117368afa7e144ace3e33f67a7e,
#                 },
#             };
#             L.control.layers(
#                 layer_control_712fd87169cd2281d5f208d1e78713ef.base_layers,
#                 layer_control_712fd87169cd2281d5f208d1e78713ef.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_6c5efb8a30a2089ea48152aa75c039b1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Make units linear

# %%
image_linear = convert_to_linear(image.select(['VV', 'VH']))
# print(image_linear.bandNames().getInfo(), image_linear.reduceRegion(ee.Reducer.minMax(), roi, 10, maxPixels=1e9).getInfo())

# %%
show_map(
    image_linear,
    roi, 
    {
        'bands': ['VV'],
        'min': [0],
        'max': [.075]
    }
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bfad23125fe69d6053b3ad46b930292 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bfad23125fe69d6053b3ad46b930292&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1bfad23125fe69d6053b3ad46b930292 = L.map(
#                 &quot;map_1bfad23125fe69d6053b3ad46b930292&quot;,
#                 {
#                     center: [41.19911137151146, -112.55089611487612],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef97fcb9f923cc4deb4bb1bcaa1e5be5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1bfad23125fe69d6053b3ad46b930292);
#
#
#             var tile_layer_ac7801fed206dcbbe0a54ec4ecaebb52 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/gsl-monitoring/maps/2b9aec66eb6d6c72b90b72079d9078af-20e78cc2beea7db40e3e41e34c8a64ee/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1bfad23125fe69d6053b3ad46b930292);
#
#
#             var layer_control_89fb7e211c35969abba710d4d8bcb2e7 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_ef97fcb9f923cc4deb4bb1bcaa1e5be5,
#                 },
#                 overlays :  {
#                     &quot;Normalized SAR Image&quot; : tile_layer_ac7801fed206dcbbe0a54ec4ecaebb52,
#                 },
#             };
#             L.control.layers(
#                 layer_control_89fb7e211c35969abba710d4d8bcb2e7.base_layers,
#                 layer_control_89fb7e211c35969abba710d4d8bcb2e7.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_1bfad23125fe69d6053b3ad46b930292);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Apply speckle filter

# %%
image_filtered = median_filter(image_linear, 7)
# print(image_filtered.bandNames().getInfo(), image_filtered.reduceRegion(ee.Reducer.minMax(), roi, 10, maxPixels=1e9).getInfo())

# %%
show_map(
    image_filtered,
    roi, 
    {
        'bands': ['VV_filtered'],
        'min': [0],
        'max': [0.075]
    }
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58d9a84db5ff2cb8fbdbecc8b0aee99e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58d9a84db5ff2cb8fbdbecc8b0aee99e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58d9a84db5ff2cb8fbdbecc8b0aee99e = L.map(
#                 &quot;map_58d9a84db5ff2cb8fbdbecc8b0aee99e&quot;,
#                 {
#                     center: [41.19911137151146, -112.55089611487612],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a225c1813d695ed1034bcc90f98ab658 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_58d9a84db5ff2cb8fbdbecc8b0aee99e);
#
#
#             var tile_layer_f3d5c5d8ef0f8b4a505ad4390c1fb3ab = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/gsl-monitoring/maps/48a187a55bee8e656329394bb0a0a6be-6dd4811869483ac1d805474871e3b612/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_58d9a84db5ff2cb8fbdbecc8b0aee99e);
#
#
#             var layer_control_91ff779b58528cbcefc3cdb7e69913b5 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a225c1813d695ed1034bcc90f98ab658,
#                 },
#                 overlays :  {
#                     &quot;Normalized SAR Image&quot; : tile_layer_f3d5c5d8ef0f8b4a505ad4390c1fb3ab,
#                 },
#             };
#             L.control.layers(
#                 layer_control_91ff779b58528cbcefc3cdb7e69913b5.base_layers,
#                 layer_control_91ff779b58528cbcefc3cdb7e69913b5.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_58d9a84db5ff2cb8fbdbecc8b0aee99e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Define ratio band

# %%
image_filtered = image_filtered.addBands(image_filtered.select('VV_filtered').divide(image_filtered.select('VH_filtered')).rename('VH_VV_filtered'))

# %% [markdown]
# ### Normalize

# %%
image_normalized = normalize(image_filtered)

# %%
band = 'VV'
show_map(
    image_normalized.select([band]), 
    roi, 
    {
        'bands': [band],
        'min': [0],
        'max': [.1]
    }
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_deaf90147787ad4fd2d87c8839ba0fe2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_deaf90147787ad4fd2d87c8839ba0fe2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_deaf90147787ad4fd2d87c8839ba0fe2 = L.map(
#                 &quot;map_deaf90147787ad4fd2d87c8839ba0fe2&quot;,
#                 {
#                     center: [41.19911137151146, -112.55089611487612],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_219d31e970912e83ffeafcce8662c79c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_deaf90147787ad4fd2d87c8839ba0fe2);
#
#
#             var tile_layer_051445b30c43b1683ccc9940dc5439ed = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/gsl-monitoring/maps/9d8080707f53b0a34c8e99c2a2962767-0863119c7876e91caffa4b59fd733c77/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_deaf90147787ad4fd2d87c8839ba0fe2);
#
#
#             var layer_control_3ca3faee82c2d2d5cf9afa8f6a64c7de = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_219d31e970912e83ffeafcce8662c79c,
#                 },
#                 overlays :  {
#                     &quot;Normalized SAR Image&quot; : tile_layer_051445b30c43b1683ccc9940dc5439ed,
#                 },
#             };
#             L.control.layers(
#                 layer_control_3ca3faee82c2d2d5cf9afa8f6a64c7de.base_layers,
#                 layer_control_3ca3faee82c2d2d5cf9afa8f6a64c7de.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_deaf90147787ad4fd2d87c8839ba0fe2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
band = 'VH'
show_map(
    image_normalized.select([band]), 
    roi, 
    {
        'bands': [band],
        'min': [0],
        'max': [.1]
    }
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_227514a913a3ec5ba74d093f2f4b8b30 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_227514a913a3ec5ba74d093f2f4b8b30&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_227514a913a3ec5ba74d093f2f4b8b30 = L.map(
#                 &quot;map_227514a913a3ec5ba74d093f2f4b8b30&quot;,
#                 {
#                     center: [41.19911137151146, -112.55089611487612],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e0041c4368810f36d6c9a2bb3fa30c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_227514a913a3ec5ba74d093f2f4b8b30);
#
#
#             var tile_layer_1ae7441aa46361f065e381df043eae22 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/gsl-monitoring/maps/55894527362202b8902d46f734f01ef9-62ef90dcef66e9c5f594354c7bebd6c5/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_227514a913a3ec5ba74d093f2f4b8b30);
#
#
#             var layer_control_b3cf7c0afe73c19842258fc51456881f = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_5e0041c4368810f36d6c9a2bb3fa30c6,
#                 },
#                 overlays :  {
#                     &quot;Normalized SAR Image&quot; : tile_layer_1ae7441aa46361f065e381df043eae22,
#                 },
#             };
#             L.control.layers(
#                 layer_control_b3cf7c0afe73c19842258fc51456881f.base_layers,
#                 layer_control_b3cf7c0afe73c19842258fc51456881f.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_227514a913a3ec5ba74d093f2f4b8b30);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
band = 'VH_VV'
show_map(
    image_normalized.select([band]), 
    roi, 
    {
        'bands': [band],
        'min': [0],
        'max': [.2]
    }
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_336434ee4217c8d5e24cd521dc810443 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_336434ee4217c8d5e24cd521dc810443&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_336434ee4217c8d5e24cd521dc810443 = L.map(
#                 &quot;map_336434ee4217c8d5e24cd521dc810443&quot;,
#                 {
#                     center: [41.19911137151146, -112.55089611487612],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c85560409b764cd3c0242d02fbfa0771 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_336434ee4217c8d5e24cd521dc810443);
#
#
#             var tile_layer_7b96e6a88d8bf89f1455bc960d1e337e = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/gsl-monitoring/maps/6afa0233a832f802484bb5adaecf418c-19a362b67bd1cd9a4a6e31ae5b773b9a/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_336434ee4217c8d5e24cd521dc810443);
#
#
#             var layer_control_80e2fa8ae5dc5f9f251e229880603d9d = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c85560409b764cd3c0242d02fbfa0771,
#                 },
#                 overlays :  {
#                     &quot;Normalized SAR Image&quot; : tile_layer_7b96e6a88d8bf89f1455bc960d1e337e,
#                 },
#             };
#             L.control.layers(
#                 layer_control_80e2fa8ae5dc5f9f251e229880603d9d.base_layers,
#                 layer_control_80e2fa8ae5dc5f9f251e229880603d9d.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_336434ee4217c8d5e24cd521dc810443);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
bands = ['VV', 'VH']
show_map(
    image_normalized.select(bands),
    roi, 
    {
        'bands': bands,
        'min': [0, 0],
        'max': [.1, .1]
    }
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6850f7e94d6d3152fa782ccc82b4320f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6850f7e94d6d3152fa782ccc82b4320f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6850f7e94d6d3152fa782ccc82b4320f = L.map(
#                 &quot;map_6850f7e94d6d3152fa782ccc82b4320f&quot;,
#                 {
#                     center: [41.19911137151146, -112.55089611487612],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d6c09b9876ca6dcf9267edb4e062497 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6850f7e94d6d3152fa782ccc82b4320f);
#
#
#             var tile_layer_d7bbaebd38551523acfc5d518fce4bfd = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/gsl-monitoring/maps/d32247804ce5d65476d0091a0302f82c-19a082f28d2273fd934a9af6c6b3e8c8/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6850f7e94d6d3152fa782ccc82b4320f);
#
#
#             var layer_control_fe3c4a0ff338e4fe1264bc97546dc93b = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_4d6c09b9876ca6dcf9267edb4e062497,
#                 },
#                 overlays :  {
#                     &quot;Normalized SAR Image&quot; : tile_layer_d7bbaebd38551523acfc5d518fce4bfd,
#                 },
#             };
#             L.control.layers(
#                 layer_control_fe3c4a0ff338e4fe1264bc97546dc93b.base_layers,
#                 layer_control_fe3c4a0ff338e4fe1264bc97546dc93b.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_6850f7e94d6d3152fa782ccc82b4320f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
bands=['VV', 'VH', 'VH_VV']
show_map(
    image_normalized.select(bands),
    roi, 
    {
        'bands': bands,
        'min': [0, 0, 0],
        'max': [.1, .1, .2]
    }
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8a9686a2cb7e4d0eeb138a3e08bff95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8a9686a2cb7e4d0eeb138a3e08bff95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8a9686a2cb7e4d0eeb138a3e08bff95 = L.map(
#                 &quot;map_a8a9686a2cb7e4d0eeb138a3e08bff95&quot;,
#                 {
#                     center: [41.19911137151146, -112.55089611487612],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1505ac45dd10a98f2eeda10e48469051 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a8a9686a2cb7e4d0eeb138a3e08bff95);
#
#
#             var tile_layer_44bf59b637c171cb90fe1aae5c1a294f = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/gsl-monitoring/maps/0c4d4d5f43115492c23ffbef8f1a35db-18c56d7552d475758128641440537556/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a8a9686a2cb7e4d0eeb138a3e08bff95);
#
#
#             var layer_control_f0fe675adb29519a3f74ca446dbe6bb9 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_1505ac45dd10a98f2eeda10e48469051,
#                 },
#                 overlays :  {
#                     &quot;Normalized SAR Image&quot; : tile_layer_44bf59b637c171cb90fe1aae5c1a294f,
#                 },
#             };
#             L.control.layers(
#                 layer_control_f0fe675adb29519a3f74ca446dbe6bb9.base_layers,
#                 layer_control_f0fe675adb29519a3f74ca446dbe6bb9.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_a8a9686a2cb7e4d0eeb138a3e08bff95);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Make bands consistent type

# %%
# make all bands float64
image_normalized = image_normalized.select(['VV', 'VH', 'VH_VV']).float()

# %% [markdown]
# ## Reproject bands to same CRS

# %%
# reproject each band individually
# print(image_normalized.getInfo())
print(image_normalized.projection().getInfo())
image_normalized = image_normalized.reproject('EPSG:6341', scale=image_normalized.projection().nominalScale())
print(image_normalized.projection().getInfo())
# image_normalized_vv = image_normalized.select(['VV']).reproject(crs='EPSG:6341', scale=image_normalized.projection().nominalScale())
# image_normalized_vh = image_normalized.select(['VH']).reproject(crs='EPSG:6341', scale=image_normalized.projection().nominalScale())
# image_normalized_vh_vv = image_normalized.select(['VH_VV']).reproject(crs='EPSG:6341', scale=image_normalized.projection().nominalScale())
# image_normalized_angle = image_normalized.select(['angle']).reproject(crs='EPSG:6341', scale=image_normalized.projection().nominalScale())
# # image_reprojected = image_normalized_vv.addBands(image_normalized_vh).addBands(image_normalized_vh_vv).addBands(image_normalized_angle)
# print(image_normalized_vv.getInfo())
# print(image_normalized_vh.getInfo())
# print(image_normalized_vh_vv.getInfo())
# print(image_normalized_angle.getInfo())
# Out:
# {'type': 'Projection', 'crs': 'EPSG:32612', 'transform': [10, 0, 265363.8038094812, 0, -10, 4661937.729569972]}
# {'type': 'Projection', 'crs': 'EPSG:6341', 'transform': [10, 0, 0, 0, -10, 0]}

# %% [markdown]
# ## Export

# %%
task = ee.batch.Export.image.toDrive(
    image=image_normalized,
    description=image.get('system:index').getInfo(),
    # scale=10, # if not provided, the native resolution of the image will be used
    maxPixels=1e13,
    region=roi.getInfo()['coordinates'],
    fileFormat='GeoTIFF',
    formatOptions={'cloudOptimized': True}
)

task.start()
task.status()
# Out:
# {'state': 'READY',
#  'description': 'S1A_IW_GRDH_1SSV_20161025T133344_20161025T133409_013647_015DFD_D6D4',
#  'creation_timestamp_ms': 1686840200863,
#  'update_timestamp_ms': 1686840200863,
#  'start_timestamp_ms': 0,
#  'task_type': 'EXPORT_IMAGE',
#  'id': 'ARTSLINRDGRD6MORPFGORTIV',
#  'name': 'projects/gsl-monitoring/operations/ARTSLINRDGRD6MORPFGORTIV'}

# %%
task.status()
# Out:
# {'state': 'READY',
#  'description': 'S1A_IW_GRDH_1SSV_20161025T133344_20161025T133409_013647_015DFD_D6D4',
#  'creation_timestamp_ms': 1686840200863,
#  'update_timestamp_ms': 1686840200863,
#  'start_timestamp_ms': 0,
#  'task_type': 'EXPORT_IMAGE',
#  'id': 'ARTSLINRDGRD6MORPFGORTIV',
#  'name': 'projects/gsl-monitoring/operations/ARTSLINRDGRD6MORPFGORTIV'}
